# %% [markdown]
# <div style='background-color:#1155CC'>
# <br>
# <p style='text-align:center; font-size:200%; color:white; font-weight:bold'>Basic Text Preprocessing</p><br>
# <p style='text-align:center; font-size:150%; color:white; font-weight:500'>Andrean Yonathan - Universitas Diponegoro</p>
# <br>
# </div>

# %% [markdown]
# <p style = 'text-align:center; font-size:250%; font-weight:bold'>Text Preprocessing</p>

# %% [markdown]
# # Import Library

# %%
import pandas as pd
import numpy as np
from emot.emo_unicode import UNICODE_EMOJI, EMOTICONS_EMO
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import contractions
import re
pd.set_option('display.max_colwidth', 150)
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. Emoji and Emoticon Normalization

# %%
def convert_emojis(text):
    for emot in UNICODE_EMOJI:
        text = text.replace(emot, '_'.join(UNICODE_EMOJI[emot].replace(',','').replace(':','').split()))
    return text

def convert_emoticons(text):
    for emot in EMOTICONS_EMO:
        text = text.replace(emot, '_'.join(EMOTICONS_EMO[emot].replace(",","").split()))
    return text

# %% [markdown]
# # 2. Contractions Normalization
#
# Reference: https://pypi.org/project/pycontractions/

# %%
def cont_to_meaning(text):
    for tx in text.split():
        if tx in contractions.contractions_dict.keys():
            text = text.replace(tx, contractions.contractions_dict[tx])
    return text

# %% [markdown]
# # 3. Text Cleaning

# %%
def text_cleaning(tx):
    tx = re.compile('rt @').sub('@', tx, count=1) # remove rt
    tx = re.sub(r"(?:\@|http|www.)\S+", " ", tx) # remove username and URL
    tx = re.sub(r'[^\x00-\x7f]', r'', tx) # remove hex character
    tx = re.sub(r'#[0-9a-zA-Z_]+', r'', tx) # remove hashtag
    tx = re.sub(r'[\d]', r'', tx) # remove number
    tx = tx.replace("\n", ' ') # remove \n
    tx = tx.replace("_", ' ') # replace underscore on emoticon
    tx = re.sub(r'[^\w\s]', '', tx) # remove punctuation
    rpt_regex = re.compile(r"(.)\1{1,}", re.IGNORECASE) # regex to normalized repeated character like hiii
    tx = rpt_regex.sub(r"\1\1", tx) # remove repeated word
    tx = tx.strip() # trim head and tail
    tx = re.sub(' +', ' ', tx) # remove multiple space
    return tx

# %% [markdown]
# # 4. Stop Words Removal

# %%
list_stopwords = stopwords.words('english')

def stopword_removal(text):
    word_list = text.split()
    text = ' '.join(i for i in word_list if i not in list_stopwords)
    return text

# %% [markdown]
# # 5. Stemming

# %%
# stemming Bahasa Inggris
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

def stem_english(text):
    text = ' '.join([stemmer.stem(tx) for tx in text.split()])
    return text

# %% [markdown]
# # 6. Tokenization

# %%
def word_token(tx):
    text = word_tokenize(tx)
    return text

# %% [markdown]
# # Function for Text Preprocessing

# %%
def text_processing(text):
    text = text.lower() # lower casing
    text = convert_emojis(text) # convert emoji
    text = convert_emoticons(text) # convert emoticon
    text = cont_to_meaning(text) # contraction normalization
    text = text_cleaning(text) # text cleaning
    text = stopword_removal(text) # stop words removal
    text = stem_english(text) # stemming
    text = word_token(text) # tokenization
    return text

# %% [markdown]
# # DATA AMAZON

# %%
data_amazon = pd.read_csv('sentiment labelled sentences/amazon_cells_labelled.csv', header = 1)
data_amazon.head()
# Out:
#                                                                          Good case  \
# 0                                                           Great for the jawbone.
# 1  Tied to charger for conversations lasting more than 45 minutes.MAJOR PROBLEMS!!
# 2                                                                The mic is great.
# 3       I have to jiggle the plug to get it to line up right to get decent volume.
# 4                            If you have several dozen or several hundred contacts
#
#                                             Excellent value.    1 Unnamed: 3  \
# 0                                                          1  NaN        NaN
# 1                                                          0  NaN        NaN
# 2                                                          1  NaN        NaN
# 3                                                          0  NaN        NaN
# 4   then imagine the fun of sending each of them one by one.    0        NaN
#
#   Unnamed: 4  Unnamed: 5
# 0        NaN         NaN
# 1        NaN         NaN
# 2        NaN         NaN
# 3        NaN         NaN
# 4        NaN         NaN

# %%
# mengambil kolom Good case dan Excellent value
data_amazon = data_amazon[['Good case', ' Excellent value.']]
data_amazon.rename(columns = {' Excellent value.' : 'Excellent value'}, inplace = True)
data_amazon.head()
# Out:
#                                                                          Good case  \
# 0                                                           Great for the jawbone.
# 1  Tied to charger for conversations lasting more than 45 minutes.MAJOR PROBLEMS!!
# 2                                                                The mic is great.
# 3       I have to jiggle the plug to get it to line up right to get decent volume.
# 4                            If you have several dozen or several hundred contacts
#
#                                              Excellent value
# 0                                                          1
# 1                                                          0
# 2                                                          1
# 3                                                          0
# 4   then imagine the fun of sending each of them one by one.

# %% [markdown]
# ## cleaning kolom Good Case

# %%
text_list = []
for text in list(data_amazon['Good case']):
    text = text_processing(text)
    text_list.append(text)
data_amazon['Good case - after'] = text_list

# %%
data_amazon.rename(columns = {'Good case' : 'Good case - before'}, inplace = True)
data_amazon[['Good case - before', 'Good case - after']]
# Out:
#                                                                   Good case - before  \
# 0                                                             Great for the jawbone.
# 1    Tied to charger for conversations lasting more than 45 minutes.MAJOR PROBLEMS!!
# 2                                                                  The mic is great.
# 3         I have to jiggle the plug to get it to line up right to get decent volume.
# 4                              If you have several dozen or several hundred contacts
# ..                                                                               ...
# 993         The screen does get smudged easily because it touches your ear and face.
# 994                          What a piece of junk.. I lose more calls on this phone.
# 995                                                     Item Does Not Match Picture.
# 996                  The only thing that disappoint me is the infra red port (irda).
# 997                                           You can not answer calls with the unit
#
#                                         Good case - after
# 0                                         [great, jawbon]
# 1    [tie, charger, convers, last, minutesmajor, problem]
# 2                                            [mic, great]
# 3     [jiggl, plug, get, line, right, get, decent, volum]
# 4                   [sever, dozen, sever, hundr, contact]
# ..                                                    ...
# 993        [screen, get, smudg, easili, touch, ear, face]
# 994                       [piec, junk, lose, call, phone]
# 995                                 [item, match, pictur]
# 996           [thing, disappoint, infra, red, port, irda]
# 997                                  [answer, call, unit]
#
# [998 rows x 2 columns]

# %% [markdown]
# ## cleaning kolom Excellent value

# %%
exc = []
for val in data_amazon['Excellent value']:
    if len(val) > 1:
        val = np.nan
    exc.append(val)
data_amazon['Excellent value'] = exc
data_amazon['Excellent value'].fillna(data_amazon['Excellent value'].median(), inplace = True)
data_amazon['Excellent value'] = data_amazon['Excellent value'].astype('int')

# %%
data_amazon[['Good case - before', 'Good case - after', 'Excellent value']]
# Out:
#                                                                   Good case - before  \
# 0                                                             Great for the jawbone.
# 1    Tied to charger for conversations lasting more than 45 minutes.MAJOR PROBLEMS!!
# 2                                                                  The mic is great.
# 3         I have to jiggle the plug to get it to line up right to get decent volume.
# 4                              If you have several dozen or several hundred contacts
# ..                                                                               ...
# 993         The screen does get smudged easily because it touches your ear and face.
# 994                          What a piece of junk.. I lose more calls on this phone.
# 995                                                     Item Does Not Match Picture.
# 996                  The only thing that disappoint me is the infra red port (irda).
# 997                                           You can not answer calls with the unit
#
#                                         Good case - after  Excellent value
# 0                                         [great, jawbon]                1
# 1    [tie, charger, convers, last, minutesmajor, problem]                0
# 2                                            [mic, great]                1
# 3     [jiggl, plug, get, line, right, get, decent, volum]                0
# 4                   [sever, dozen, sever, hundr, contact]                1
# ..                                                    ...              ...
# 993        [screen, get, smudg, easili, touch, ear, face]                0
# 994                       [piec, junk, lose, call, phone]                0
# 995                                 [item, match, pictur]                0
# 996           [thing, disappoint, infra, red, port, irda]                0
# 997                                  [answer, call, unit]                1
#
# [998 rows x 3 columns]

# %% [markdown]
# # DATA IMDB

# %%
data_imdb = pd.read_csv('sentiment labelled sentences/imdb_labelled.csv')
data_imdb.head()
# Out:
#                                                                                                          A very  \
# 0                                              Not sure who was more lost - the flat characters or the audience
# 1                                               Attempting artiness with black & white and clever camera angles
# 2                                                                  Very little music or anything to speak of.
# 3  The best scene in the movie was when Gerardo is trying to find a song that keeps running through his head.
# 4                                                                               The rest of the movie lacks art
#
#                                                                                                                            very  \
# 0                                                                                             nearly half of whom walked out.
# 1   the movie disappointed - became even more ridiculous - as the acting was poor and the plot and lines almost non-existent.
# 2                                                                                                                             0
# 3                                                                                                                             1
# 4                                                                                                                         charm
#
#                       very slow-moving  \
# 0                                    0
# 1                                    0
# 2                                  NaN
# 3                                  NaN
# 4   meaning... If it's about emptiness
#
#           aimless movie about a distressed  drifting young man.      0  \
# 0                                      NaN                    NaN  NaN
# 1                                      NaN                    NaN  NaN
# 2                                      NaN                    NaN  NaN
# 3                                      NaN                    NaN  NaN
# 4   it works I guess because it's empty.                        0  NaN
#
#   Unnamed: 6  Unnamed: 7
# 0        NaN         NaN
# 1        NaN         NaN
# 2        NaN         NaN
# 3        NaN         NaN
# 4        NaN         NaN

# %%
# rename kolom 'A very' menjadi 'text - before'
data_imdb.rename(columns = {'A very' : 'text - before'}, inplace = True)
data_imdb.head()
# Out:
#                                                                                                   text - before  \
# 0                                              Not sure who was more lost - the flat characters or the audience
# 1                                               Attempting artiness with black & white and clever camera angles
# 2                                                                  Very little music or anything to speak of.
# 3  The best scene in the movie was when Gerardo is trying to find a song that keeps running through his head.
# 4                                                                               The rest of the movie lacks art
#
#                                                                                                                            very  \
# 0                                                                                             nearly half of whom walked out.
# 1   the movie disappointed - became even more ridiculous - as the acting was poor and the plot and lines almost non-existent.
# 2                                                                                                                             0
# 3                                                                                                                             1
# 4                                                                                                                         charm
#
#                       very slow-moving  \
# 0                                    0
# 1                                    0
# 2                                  NaN
# 3                                  NaN
# 4   meaning... If it's about emptiness
#
#           aimless movie about a distressed  drifting young man.      0  \
# 0                                      NaN                    NaN  NaN
# 1                                      NaN                    NaN  NaN
# 2                                      NaN                    NaN  NaN
# 3                                      NaN                    NaN  NaN
# 4   it works I guess because it's empty.                        0  NaN
#
#   Unnamed: 6  Unnamed: 7
# 0        NaN         NaN
# 1        NaN         NaN
# 2        NaN         NaN
# 3        NaN         NaN
# 4        NaN         NaN

# %% [markdown]
# ## cleaning kolom text

# %%
text_list = []
for text in list(data_imdb['text - before']):
    text = text_processing(text)
    text_list.append(text)
data_imdb['text - after'] = text_list

# %%
data_imdb[['text - before', 'text - after']].head()
# Out:
#                                                                                                   text - before  \
# 0                                              Not sure who was more lost - the flat characters or the audience
# 1                                               Attempting artiness with black & white and clever camera angles
# 2                                                                  Very little music or anything to speak of.
# 3  The best scene in the movie was when Gerardo is trying to find a song that keeps running through his head.
# 4                                                                               The rest of the movie lacks art
#
#                                                      text - after
# 0                            [sure, lost, flat, charact, audienc]
# 1             [attempt, arti, black, white, clever, camera, angl]
# 2                                    [littl, music, anyth, speak]
# 3  [best, scene, movi, gerardo, tri, find, song, keep, run, head]
# 4                                         [rest, movi, lack, art]

# %% [markdown]
# # DATA YELP

# %%
data_yelp = pd.read_csv('sentiment labelled sentences/yelp_labelled.csv', header = None)
data_yelp.head()
# Out:
#                                                                                          0  \
# 0                                                                 Wow... Loved this place.
# 1                                                                       Crust is not good.
# 2                                                Not tasty and the texture was just nasty.
# 3  Stopped by during the late May bank holiday off Rick Steve recommendation and loved it.
# 4                              The selection on the menu was great and so were the prices.
#
#    1    2    3    4   5
# 0  1  NaN  NaN  NaN NaN
# 1  0  NaN  NaN  NaN NaN
# 2  0  NaN  NaN  NaN NaN
# 3  1  NaN  NaN  NaN NaN
# 4  1  NaN  NaN  NaN NaN

# %%
# rename kolom '0' menjadi 'text - before'
data_yelp.rename(columns = {0 : 'text - before'}, inplace = True)
data_yelp.head()
# Out:
#                                                                              text - before  \
# 0                                                                 Wow... Loved this place.
# 1                                                                       Crust is not good.
# 2                                                Not tasty and the texture was just nasty.
# 3  Stopped by during the late May bank holiday off Rick Steve recommendation and loved it.
# 4                              The selection on the menu was great and so were the prices.
#
#    1    2    3    4   5
# 0  1  NaN  NaN  NaN NaN
# 1  0  NaN  NaN  NaN NaN
# 2  0  NaN  NaN  NaN NaN
# 3  1  NaN  NaN  NaN NaN
# 4  1  NaN  NaN  NaN NaN

# %% [markdown]
# ## cleaning kolom 'text - before'

# %%
text_list = []
for text in list(data_yelp['text - before']):
    text = text_processing(text)
    text_list.append(text)
data_yelp['text - after'] = text_list

# %%
data_yelp[['text - before', 'text - after']].head()
# Out:
#                                                                              text - before  \
# 0                                                                 Wow... Loved this place.
# 1                                                                       Crust is not good.
# 2                                                Not tasty and the texture was just nasty.
# 3  Stopped by during the late May bank holiday off Rick Steve recommendation and loved it.
# 4                              The selection on the menu was great and so were the prices.
#
#                                                      text - after
# 0                                              [wow, love, place]
# 1                                                   [crust, good]
# 2                                          [tasti, textur, nasti]
# 3  [stop, late, may, bank, holiday, rick, steve, recommend, love]
# 4                                    [select, menu, great, price]
